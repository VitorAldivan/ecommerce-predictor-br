# %%
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "kagglehub"])

import kagglehub
path = kagglehub.dataset_download("olistbr/brazilian-ecommerce")
print("✅ Dataset:", path)

import pandas as pd
orders = pd.read_csv(path + '/olist_orders_dataset.csv')
print("✅ SHAPE:", orders.shape)
print("📅 Período:", orders['order_purchase_timestamp'].min()[:7], "até", orders['order_purchase_timestamp'].max()[:7])
print("Estados:", pd.read_csv(path + '/olist_customers_dataset.csv')['customer_state'].nunique())
# Out:
# Downloading to C:\Users\aldiv\.cache\kagglehub\datasets\olistbr\brazilian-ecommerce\2.archive...
# 100%|█████████████████████████████████████| 42.6M/42.6M [00:02<00:00, 21.0MB/s]
# Extracting files...
# ✅ Dataset: C:\Users\aldiv\.cache\kagglehub\datasets\olistbr\brazilian-ecommerce\versions\2
# ✅ SHAPE: (99441, 8)
# 📅 Período: 2016-09 até 2018-10
# Estados: 27
